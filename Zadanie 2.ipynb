# %%
import numpy as nmp
import pandas as pnd
import seaborn as sns
df = pnd.read_table('dane2.dat', sep=' ')
classes = set(df.klasa)

# %% [markdown]
# # Zadanie 2
# Oceń wizualnie (analizując wykresy punktowe, macierz wykresów punktowych) czy podział na grupy reprezentowany przez atrybut decyzyjny odpowiada naturalnym skupieniom danych w przestrzeni atrybutów.

# %%
# %matplotlib inline
sns.set(style="ticks", color_codes=True)
sns.pairplot(df, hue="klasa")

# %% [markdown]
# Jak widać na wykresach (atrybut2, atrybut3) oraz (atrybut3, atrybut2), podział na grupy reprezentowany przez atrybut decyzyjny nie odpowiada naturalnym skupieniom danych w przestrzeni atrybutów. Skupiska nakładają się na siebie, nie ma wyraźnych granic pomiędzy nimi. W pozostałych przypadkach rzeczywiście podział na grupy przez atrybut decyzyjny odpowiada naturalnym skupieniom danych w przestrzeni atrybutów.
